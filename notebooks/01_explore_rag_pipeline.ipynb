# %% [markdown]
# # RAG Pipeline Exploration
# End-to-end demo: ingest a document → embed → retrieve → answer with Claude.

# %%
import sys
sys.path.insert(0, '..')

from dotenv import load_dotenv
load_dotenv('../.env')

# %%
from src.llm.rag_pipeline import RAGPipeline

pipeline = RAGPipeline(vector_store_dir='../data/vector_store')
print('Pipeline ready. Chunks in store:', pipeline.stats()['total_chunks'])

# %%
# Ingest a sample document
# pipeline.ingest_file('../data/raw/your_document.pdf')

# %%
# Query the pipeline
question = 'What is this document about?'
answer = pipeline.query(question)
